# %% [markdown]
# # Human Activity Recognition from Pose
#
# **Author:** _TODO: add name_
#
# ---

# %% [markdown]
# ##Installation

# %%
# !pip install -q kagglehub

# TODO: Install your dependencies here

# %% [markdown]
# ##Imports

# %%
import os
import shutil
from glob import glob
import kagglehub  # Official Kaggle helper library to download datasets programmatically

# TODO: Import your dependences here

# %% [markdown]
# ## 1. Introduction
#
# _TODO: Briefly describe the problem you are solving, why pose-based HAR is interesting, and what you aim to achieve in this notebook._

# %% [markdown]
# ## 2. Dataset description
#
# _TODO: Describe the Kaggle dataset (classes, number of videos, typical duration, scenarios, etc.)._

# %% [markdown]
# ## 3. Selected pose model
#
# _TODO: Explain which pose estimation model you will use (e.g., MediaPipe Pose Landmarker, RTMPose, etc.), why you chose it, and what output it produces (2D/3D keypoints, number of joints, etc.)._

# %% [markdown]
# ## 4. Dataset loading
#
# In this section we automatically download the Kaggle dataset and organize it into a convenient folder structure.

# %%
download_url = "https://unialicante-my.sharepoint.com/:u:/g/personal/chs17_mscloud_ua_es/IQDC3NK9kdnYS7sqRU-ODRFiAdTjADSXk9cJ237N2KyGtbQ?e=xT32pr&download=1"

# !wget -O /content/har_dataset.zip "$download_url"
# !file /content/har_dataset.zip
# !ls -lh /content/har_dataset.zip

# %%
# !mkdir -p /content/dataset
# !unzip -q /content/har_dataset.zip -d /content/dataset
# !find /content/dataset -maxdepth 2 -type d

# %% [markdown]
# ## 5. Pose extraction
#
# _TODO: Implement and describe how you extract pose keypoints from each video (model initialization, frame sampling, handling of missing detections, etc.)._

# %% [markdown]
# ## 6. Sequence preprocessing
#
# _TODO: Explain how you transform raw keypoint sequences into model-ready inputs (normalization, fixed-length sequences, feature engineering, etc.)._

# %% [markdown]
# ## 7. Classification model definition
#
# _TODO: Define and justify the architecture you will use for HAR (e.g., LSTM, 1D-CNN, GCN, MLP on features, etc.)._

# %% [markdown]
# ## 8. Training
#
# _TODO: Describe your training setup (train/val split, loss function, optimizer, main hyperparameters, number of epochs, early stopping criteria, etc.)._

# %%
EPOCHS = 10 # IMPORTANT: You musn't modify the epochs value

for epoch in range(1, EPOCHS + 1):
  # TODO: Complete the training loop
  pass

# %% [markdown]
# ## 9. Evaluation
#
# _TODO: Compute and report the main metrics (accuracy, precision, recall, macro F1-score) on the test set._

# %% [markdown]
# ## 10. Confusion matrix and results
#
# _TODO: Show the confusion matrix, a summary table of results, and optionally some illustrative examples (e.g., correctly vs. incorrectly classified videos)._

# %% [markdown]
# ## 11. Error analysis
#
# _TODO: Analyze which activities are most often confused, discuss whether the errors come from pose estimation or from the classifier, and relate them to properties of the dataset (occlusions, camera angle, etc.)._

# %% [markdown]
# ## 12. Conclusions
#
# _TODO: Summarize what you built, what you learned, the overall performance obtained, and possible future improvements to the pipeline._
